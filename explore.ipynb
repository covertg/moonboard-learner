# %%
import pandas as pd
from moon import problem

# %%
probs = pd.read_csv('data/cleaned_probs.csv')
probs.rename(columns=lambda s: s.replace('.', '_'), inplace=True)  # Remove . because itertuples() won't accept them

# %%
p = [problem.Problem(t) for t in probs.itertuples()]

# %%
display(p)
# Out:
# [Problem(name=PROBLEM 14, grade=7B, setter=lucas Dourdourekas, rating=3, repeats=3, benchmark=False, master=False, assessment=False, type=ProblemType.Other),
#  Problem(name=PROBLEM 13, grade=7A, setter=lucas Dourdourekas, rating=3, repeats=43, benchmark=False, master=False, assessment=False, type=ProblemType.Other),
#  Problem(name=PROBLEM 12, grade=7B, setter=lucas Dourdourekas, rating=3, repeats=6, benchmark=False, master=False, assessment=False, type=ProblemType.Other),
#  Problem(name=PROBLEM 11, grade=7A, setter=lucas Dourdourekas, rating=3, repeats=1576, benchmark=True, master=False, assessment=False, type=ProblemType.Other),
#  Problem(name=TESS, grade=6C+, setter=Ben Moon, rating=3, repeats=4582, benchmark=True, master=False, assessment=False, type=ProblemType.Other),
#  Problem(name=PROBLEM 9, grade=7A+, setter=Ally Patrick, rating=3, repeats=1219, benchmark=True, master=False, assessment=False, type=ProblemType.Other),
# ...
