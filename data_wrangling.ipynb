# %% [markdown]
# # MoonBoard Data Wranglin'

# %% [markdown]
# ### Acquisition

# %%
! ./data/download.sh
# Out:
# File raw_probs.out already exists! Aborting to avoid an overwrite.
# # Lines, # Bytes:    2069 87184241

# %% [markdown]
# ### First exploration

# %%
import pandas as pd

# With lines=True we can read the multi-json file all in one go. Each line is a different json dict,
# but they all get bound together appropriately. (Each page is a row.)
df = pd.read_json('data/raw_probs.out', lines=True)

# %% [markdown]
# Check it out...

# %%
display(df.sample(10))
# Out:
#                                             TknDts  \
# 224   cOjCiKtygP4zOcstW+p4vfg2dkxjojqP4MIaVPRypgI=
# 1263  LqjSyCj2soGLq+FN2+Hz9aACj7Wg0/YVF0mw9wZjF+Q=
# 1024  bRxk6hs1Z61nOgW5h2kzBT+pzvPCWgLMH66J82ZBcjk=
# 172   L7FFCV1wqHK84W8zPCnAoMoxKxthNkodPxIXm4I+6/s=
# 1332  gTDdgZQWhsGYm/4aTASXJFvIaAiE68OyZ9CmpHdYXtc=
# 649   FqmBxWKrHN0GTcqWVIX98pkv8LAcGbka2tIgKL9upKI=
# 1949  RINWMbRPckRhZzB0eck4bvzqwVfzc0ZetAvXrh3qdBc=
# 908   bGSdUTuSbWCGJZOoduIgigqNp5+0bVKE/tL9QLzsHGQ=
# 803   2AQT0E17pWskP8TawLBeu5r3HlVzHfjy4IgigUvofug=
# 392   zBldeU6saSTMIfBFeu0xzEvEe93DaMGC56ryxZaduhM=
#
#                                                    Data  Total  \
# 224   [{'Method': 'Feet follow hands', 'Name': 'NOBI...  31034
# 1263  [{'Method': 'Feet follow hands', 'Name': 'CAMP...  31034
# 1024  [{'Method': 'Feet follow hands', 'Name': 'LE P...  31034
# 172   [{'Method': 'Feet follow hands', 'Name': 'F18 ...  31034
# 1332  [{'Method': 'Feet follow hands', 'Name': 'LEFT...  31034
# 649   [{'Method': 'Feet follow hands', 'Name': 'ランジラ...  31034
# 1949  [{'Method': 'Feet follow hands', 'Name': 'INTE...  31035
# 908   [{'Method': 'Feet follow hands', 'Name': 'SNOW...  31034
# 803   [{'Method': 'Feet follow hands', 'Name': 'BARN...  31034
# 392   [{'Method': 'Feet follow hands', 'Name': 'TEST...  31034
#
#       AggregateResults  Errors
# 224                NaN     NaN
# 1263               NaN     NaN
# 1024               NaN     NaN
# 172                NaN     NaN
# 1332               NaN     NaN
# 649                NaN     NaN
# 1949               NaN     NaN
# 908                NaN     NaN
# 803                NaN     NaN
# 392                NaN     NaN

# %% [markdown]
# It seems like the only relevant data (to us) might be the 'Data' column. Yeah?

# %%
# Are any of these not NaN?
print((~df['Errors'].isnull()).any())
print((~df['AggregateResults'].isnull()).any())
# (Nope)
# Out:
# False
# False

# %% [markdown]
# Yeah. And in fact 'Data' holds 15 problems each, since it represents the 15 problems of each "page" on the website.

# %%
display(df['Data'][0])
pd.DataFrame.from_records(df['Data'][0])
# Out:
# [{'Method': 'Feet follow hands',
#   'Name': 'PROBLEM 14',
#   'Grade': '7B',
#   'UserGrade': None,
#   'MoonBoardConfiguration': None,
#   'MoonBoardConfigurationId': 0,
#   'Setter': {'Id': '48B03D33-7FB0-43A9-BC1C-F9B75B2EFA13',
#    'Nickname': 'lucas Dourdourekas',
#    'Firstname': 'lucas',
#    'Lastname': 'Dourdourekas',
#    'City': 'Kalymnos',
#    'Country': 'GREECE ',
#    'ProfileImageUrl': '/Content/Account/Images/default-profile.png?637253886636747434',
#    'CanShareData': True},
#   'FirstAscender': False,
#   'Rating': 0,
#   'UserRating': 3,
#   'Repeats': 3,
#   'Attempts': 0,
#   'Holdsetup': {'Id': 1,
#    'Description': 'MoonBoard 2016',
#    'Setby': None,
#    'DateInserted': None,
#    'DateUpdated': None,
#    'DateDeleted': None,
#    'IsLocked': False,
#    'IsMini': False,
#    'Active': False,
#    'Holdsets': None,
#    'MoonBoardConfigurations': None,
#    'HoldLayoutId': 0,
#    'AllowClimbMethods': False},
#   'IsBenchmark': False,
#   'IsMaster': False,
#   'IsAssessmentProblem': False,
#   'ProblemType': None,
#   'Moves': [{'Id': 1518093,
#     'Description': 'G4',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 1518094, 'Description': 'B7', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518095, 'Description': 'G8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518096, 'Description': 'D11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518097, 'Description': 'C13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518098, 'Description': 'G17', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518099, 'Description': 'I18', 'IsStart': False, 'IsEnd': True}],
#   'Holdsets': None,
#   'Locations': [{'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 145,
#     'Y': 636,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 195,
#     'Y': 338,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 245,
#     'Y': 436,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 395,
#     'Y': 788,
#     'Color': '0x00FF00',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 395,
#     'Y': 588,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 395,
#     'Y': 138,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 495,
#     'Y': 88,
#     'Color': '0xFF0000',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'}],
#   'RepeatText': '3 climbers  have repeated this problem',
#   'NumberOfTries': None,
#   'NameForUrl': 'problem-14',
#   'Upgraded': False,
#   'Downgraded': False,
#   'Id': 19228,
#   'ApiId': 19228,
#   'DateInserted': '/Date(1456826414000)/',
#   'DateUpdated': None,
#   'DateDeleted': None,
#   'DateTimeString': '01 Mar 2016 10:00'},
#  {'Method': 'Feet follow hands',
#   'Name': 'PROBLEM 13',
#   'Grade': '7A',
#   'UserGrade': '7A',
#   'MoonBoardConfiguration': None,
#   'MoonBoardConfigurationId': 0,
#   'Setter': {'Id': '48B03D33-7FB0-43A9-BC1C-F9B75B2EFA13',
#    'Nickname': 'lucas Dourdourekas',
#    'Firstname': 'lucas',
#    'Lastname': 'Dourdourekas',
#    'City': 'Kalymnos',
#    'Country': 'GREECE ',
#    'ProfileImageUrl': '/Content/Account/Images/default-profile.png?637253886636903684',
#    'CanShareData': True},
#   'FirstAscender': False,
#   'Rating': 0,
#   'UserRating': 3,
#   'Repeats': 43,
#   'Attempts': 0,
#   'Holdsetup': {'Id': 1,
#    'Description': 'MoonBoard 2016',
#    'Setby': None,
#    'DateInserted': None,
#    'DateUpdated': None,
#    'DateDeleted': None,
#    'IsLocked': False,
#    'IsMini': False,
#    'Active': False,
#    'Holdsets': None,
#    'MoonBoardConfigurations': None,
#    'HoldLayoutId': 0,
#    'AllowClimbMethods': False},
#   'IsBenchmark': False,
#   'IsMaster': False,
#   'IsAssessmentProblem': False,
#   'ProblemType': None,
#   'Moves': [{'Id': 1518087,
#     'Description': 'I4',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 1518088, 'Description': 'E7', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518089, 'Description': 'H11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518090, 'Description': 'D12', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518091, 'Description': 'B16', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518092, 'Description': 'G18', 'IsStart': False, 'IsEnd': True}],
#   'Holdsets': None,
#   'Locations': [{'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 145,
#     'Y': 186,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 245,
#     'Y': 386,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 295,
#     'Y': 638,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 395,
#     'Y': 88,
#     'Color': '0xFF0000',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 445,
#     'Y': 436,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 495,
#     'Y': 788,
#     'Color': '0x00FF00',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'}],
#   'RepeatText': '43 climbers  have repeated this problem',
#   'NumberOfTries': None,
#   'NameForUrl': 'problem-13',
#   'Upgraded': False,
#   'Downgraded': False,
#   'Id': 19227,
#   'ApiId': 19227,
#   'DateInserted': '/Date(1456826414000)/',
#   'DateUpdated': None,
#   'DateDeleted': None,
#   'DateTimeString': '01 Mar 2016 10:00'},
#  {'Method': 'Feet follow hands',
#   'Name': 'PROBLEM 12',
#   'Grade': '7B',
#   'UserGrade': None,
#   'MoonBoardConfiguration': None,
#   'MoonBoardConfigurationId': 0,
#   'Setter': {'Id': '48B03D33-7FB0-43A9-BC1C-F9B75B2EFA13',
#    'Nickname': 'lucas Dourdourekas',
#    'Firstname': 'lucas',
#    'Lastname': 'Dourdourekas',
#    'City': 'Kalymnos',
#    'Country': 'GREECE ',
#    'ProfileImageUrl': '/Content/Account/Images/default-profile.png?637253886636903684',
#    'CanShareData': True},
#   'FirstAscender': False,
#   'Rating': 0,
#   'UserRating': 3,
#   'Repeats': 6,
#   'Attempts': 0,
#   'Holdsetup': {'Id': 1,
#    'Description': 'MoonBoard 2016',
#    'Setby': None,
#    'DateInserted': None,
#    'DateUpdated': None,
#    'DateDeleted': None,
#    'IsLocked': False,
#    'IsMini': False,
#    'Active': False,
#    'Holdsets': None,
#    'MoonBoardConfigurations': None,
#    'HoldLayoutId': 0,
#    'AllowClimbMethods': False},
#   'IsBenchmark': False,
#   'IsMaster': False,
#   'IsAssessmentProblem': False,
#   'ProblemType': None,
#   'Moves': [{'Id': 1518081,
#     'Description': 'G6',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 1518082, 'Description': 'K9', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518083, 'Description': 'H12', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518084, 'Description': 'G14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518085, 'Description': 'B15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518086, 'Description': 'A18', 'IsStart': False, 'IsEnd': True}],
#   'Holdsets': None,
#   'Locations': [{'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 95,
#     'Y': 88,
#     'Color': '0xFF0000',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 145,
#     'Y': 236,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 395,
#     'Y': 688,
#     'Color': '0x00FF00',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 395,
#     'Y': 288,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 445,
#     'Y': 386,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 595,
#     'Y': 538,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'}],
#   'RepeatText': '6 climbers  have repeated this problem',
#   'NumberOfTries': None,
#   'NameForUrl': 'problem-12',
#   'Upgraded': False,
#   'Downgraded': False,
#   'Id': 19226,
#   'ApiId': 19226,
#   'DateInserted': '/Date(1456826415000)/',
#   'DateUpdated': None,
#   'DateDeleted': None,
#   'DateTimeString': '01 Mar 2016 10:00'},
#  {'Method': 'Feet follow hands',
#   'Name': 'PROBLEM 11',
#   'Grade': '7A',
#   'UserGrade': '7A',
#   'MoonBoardConfiguration': None,
#   'MoonBoardConfigurationId': 0,
#   'Setter': {'Id': '48B03D33-7FB0-43A9-BC1C-F9B75B2EFA13',
#    'Nickname': 'lucas Dourdourekas',
#    'Firstname': 'lucas',
#    'Lastname': 'Dourdourekas',
#    'City': 'Kalymnos',
#    'Country': 'GREECE ',
#    'ProfileImageUrl': '/Content/Account/Images/default-profile.png?637253886650044772',
#    'CanShareData': True},
#   'FirstAscender': False,
#   'Rating': 0,
#   'UserRating': 3,
#   'Repeats': 1576,
#   'Attempts': 0,
#   'Holdsetup': {'Id': 1,
#    'Description': 'MoonBoard 2016',
#    'Setby': None,
#    'DateInserted': None,
#    'DateUpdated': None,
#    'DateDeleted': None,
#    'IsLocked': False,
#    'IsMini': False,
#    'Active': False,
#    'Holdsets': None,
#    'MoonBoardConfigurations': None,
#    'HoldLayoutId': 0,
#    'AllowClimbMethods': False},
#   'IsBenchmark': True,
#   'IsMaster': False,
#   'IsAssessmentProblem': False,
#   'ProblemType': None,
#   'Moves': [{'Id': 1518074,
#     'Description': 'C5',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 1518075, 'Description': 'B6', 'IsStart': True, 'IsEnd': False},
#    {'Id': 1518076, 'Description': 'E8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518077, 'Description': 'B10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518078, 'Description': 'E14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518079, 'Description': 'E16', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518080, 'Description': 'I18', 'IsStart': False, 'IsEnd': True}],
#   'Holdsets': None,
#   'Locations': [{'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 145,
#     'Y': 486,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 145,
#     'Y': 686,
#     'Color': '0x00FF00',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 195,
#     'Y': 738,
#     'Color': '0x00FF00',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 295,
#     'Y': 588,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 295,
#     'Y': 288,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 295,
#     'Y': 188,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 495,
#     'Y': 88,
#     'Color': '0xFF0000',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'}],
#   'RepeatText': '1576 climbers  have repeated this problem',
#   'NumberOfTries': None,
#   'NameForUrl': 'problem-11',
#   'Upgraded': False,
#   'Downgraded': False,
#   'Id': 19225,
#   'ApiId': 19225,
#   'DateInserted': '/Date(1456826414000)/',
#   'DateUpdated': None,
#   'DateDeleted': None,
#   'DateTimeString': '01 Mar 2016 10:00'},
#  {'Method': 'Feet follow hands',
#   'Name': 'TESS',
#   'Grade': '6C+',
#   'UserGrade': '6C+',
#   'MoonBoardConfiguration': None,
#   'MoonBoardConfigurationId': 0,
#   'Setter': {'Id': '5FC09F63-05F3-4DAE-A1A5-3AC22C37139A',
#    'Nickname': 'Ben Moon',
#    'Firstname': 'Ben',
#    'Lastname': 'Moon',
#    'City': 'Sheffield',
#    'Country': 'United Kingdom',
#    'ProfileImageUrl': '/Content/Account/Users/Profile/5FC09F63-05F3-4DAE-A1A5-3AC22C37139A.jpeg?637253886692085371',
#    'CanShareData': True},
#   'FirstAscender': False,
#   'Rating': 0,
#   'UserRating': 3,
#   'Repeats': 4582,
#   'Attempts': 0,
#   'Holdsetup': {'Id': 1,
#    'Description': 'MoonBoard 2016',
#    'Setby': None,
#    'DateInserted': None,
#    'DateUpdated': None,
#    'DateDeleted': None,
#    'IsLocked': False,
#    'IsMini': False,
#    'Active': False,
#    'Holdsets': None,
#    'MoonBoardConfigurations': None,
#    'HoldLayoutId': 0,
#    'AllowClimbMethods': False},
#   'IsBenchmark': True,
#   'IsMaster': False,
#   'IsAssessmentProblem': False,
#   'ProblemType': None,
#   'Moves': [{'Id': 1518065,
#     'Description': 'F5',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 1518066, 'Description': 'I5', 'IsStart': True, 'IsEnd': False},
#    {'Id': 1518067, 'Description': 'F9', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518068, 'Description': 'C10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518069, 'Description': 'F11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518070, 'Description': 'C14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518071, 'Description': 'C15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518072, 'Description': 'E18', 'IsStart': False, 'IsEnd': True},
#    {'Id': 1518073, 'Description': 'E18', 'IsStart': False, 'IsEnd': True}],
#   'Holdsets': None,
#   'Locations': [{'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 195,
#     'Y': 488,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 195,
#     'Y': 288,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 195,
#     'Y': 238,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 295,
#     'Y': 88,
#     'Color': '0xFF0000',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 345,
#     'Y': 436,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 345,
#     'Y': 536,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 345,
#     'Y': 736,
#     'Color': '0x00FF00',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 495,
#     'Y': 738,
#     'Color': '0x00FF00',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'}],
#   'RepeatText': '4582 climbers  have repeated this problem',
#   'NumberOfTries': None,
#   'NameForUrl': 'tess',
#   'Upgraded': False,
#   'Downgraded': False,
#   'Id': 19224,
#   'ApiId': 19224,
#   'DateInserted': '/Date(1456826415000)/',
#   'DateUpdated': None,
#   'DateDeleted': None,
#   'DateTimeString': '01 Mar 2016 10:00'},
#  {'Method': 'Feet follow hands',
#   'Name': 'PROBLEM 9',
#   'Grade': '7A+',
#   'UserGrade': '7A+',
#   'MoonBoardConfiguration': None,
#   'MoonBoardConfigurationId': 0,
#   'Setter': {'Id': 'CC7D7BD1-67CD-4027-A537-22E7855C18B7',
#    'Nickname': 'Ally Patrick',
#    'Firstname': 'Alistair',
#    'Lastname': 'Patrick',
#    'City': 'Manchester',
#    'Country': 'United Kingdom',
#    'ProfileImageUrl': '/Content/Account/Images/default-profile.png?637253886695366613',
#    'CanShareData': True},
#   'FirstAscender': False,
#   'Rating': 0,
#   'UserRating': 3,
#   'Repeats': 1219,
#   'Attempts': 0,
#   'Holdsetup': {'Id': 1,
#    'Description': 'MoonBoard 2016',
#    'Setby': None,
#    'DateInserted': None,
#    'DateUpdated': None,
#    'DateDeleted': None,
#    'IsLocked': False,
#    'IsMini': False,
#    'Active': False,
#    'Holdsets': None,
#    'MoonBoardConfigurations': None,
#    'HoldLayoutId': 0,
#    'AllowClimbMethods': False},
#   'IsBenchmark': True,
#   'IsMaster': False,
#   'IsAssessmentProblem': False,
#   'ProblemType': None,
#   'Moves': [{'Id': 1518059,
#     'Description': 'J5',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 1518060, 'Description': 'H8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518061, 'Description': 'C10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518062, 'Description': 'E13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518063, 'Description': 'B16', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518064, 'Description': 'G18', 'IsStart': False, 'IsEnd': True}],
#   'Holdsets': None,
#   'Locations': [{'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 145,
#     'Y': 186,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 195,
#     'Y': 488,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 295,
#     'Y': 338,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 395,
#     'Y': 88,
#     'Color': '0xFF0000',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 445,
#     'Y': 586,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 545,
#     'Y': 736,
#     'Color': '0x00FF00',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'}],
#   'RepeatText': '1219 climbers  have repeated this problem',
#   'NumberOfTries': None,
#   'NameForUrl': 'problem-9',
#   'Upgraded': False,
#   'Downgraded': False,
#   'Id': 19223,
#   'ApiId': 19223,
#   'DateInserted': '/Date(1456826415000)/',
#   'DateUpdated': None,
#   'DateDeleted': None,
#   'DateTimeString': '01 Mar 2016 10:00'},
#  {'Method': 'Feet follow hands',
#   'Name': 'VURT',
#   'Grade': '7B',
#   'UserGrade': '7B',
#   'MoonBoardConfiguration': None,
#   'MoonBoardConfigurationId': 0,
#   'Setter': {'Id': '5FC09F63-05F3-4DAE-A1A5-3AC22C37139A',
#    'Nickname': 'Ben Moon',
#    'Firstname': 'Ben',
#    'Lastname': 'Moon',
#    'City': 'Sheffield',
#    'Country': 'United Kingdom',
#    'ProfileImageUrl': '/Content/Account/Users/Profile/5FC09F63-05F3-4DAE-A1A5-3AC22C37139A.jpeg?637253886696616610',
#    'CanShareData': True},
#   'FirstAscender': False,
#   'Rating': 0,
#   'UserRating': 3,
#   'Repeats': 681,
#   'Attempts': 0,
#   'Holdsetup': {'Id': 1,
#    'Description': 'MoonBoard 2016',
#    'Setby': None,
#    'DateInserted': None,
#    'DateUpdated': None,
#    'DateDeleted': None,
#    'IsLocked': False,
#    'IsMini': False,
#    'Active': False,
#    'Holdsets': None,
#    'MoonBoardConfigurations': None,
#    'HoldLayoutId': 0,
#    'AllowClimbMethods': False},
#   'IsBenchmark': True,
#   'IsMaster': False,
#   'IsAssessmentProblem': False,
#   'ProblemType': None,
#   'Moves': [{'Id': 1518053,
#     'Description': 'B3',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 1518054, 'Description': 'E7', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518055, 'Description': 'C10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518056, 'Description': 'F12', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518057, 'Description': 'G14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518058, 'Description': 'I18', 'IsStart': False, 'IsEnd': True}],
#   'Holdsets': None,
#   'Locations': [{'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 145,
#     'Y': 836,
#     'Color': '0x00FF00',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 195,
#     'Y': 488,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 295,
#     'Y': 638,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 345,
#     'Y': 386,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 395,
#     'Y': 288,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 495,
#     'Y': 88,
#     'Color': '0xFF0000',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'}],
#   'RepeatText': '681 climbers  have repeated this problem',
#   'NumberOfTries': None,
#   'NameForUrl': 'vurt',
#   'Upgraded': False,
#   'Downgraded': False,
#   'Id': 19222,
#   'ApiId': 19222,
#   'DateInserted': '/Date(1456826415000)/',
#   'DateUpdated': None,
#   'DateDeleted': None,
#   'DateTimeString': '01 Mar 2016 10:00'},
#  {'Method': 'Feet follow hands',
#   'Name': 'SHORTROUND',
#   'Grade': '6C+',
#   'UserGrade': '6C+',
#   'MoonBoardConfiguration': None,
#   'MoonBoardConfigurationId': 0,
#   'Setter': {'Id': 'CC7D7BD1-67CD-4027-A537-22E7855C18B7',
#    'Nickname': 'Ally Patrick',
#    'Firstname': 'Alistair',
#    'Lastname': 'Patrick',
#    'City': 'Manchester',
#    'Country': 'United Kingdom',
#    'ProfileImageUrl': '/Content/Account/Images/default-profile.png?637253886697241608',
#    'CanShareData': True},
#   'FirstAscender': False,
#   'Rating': 0,
#   'UserRating': 3,
#   'Repeats': 308,
#   'Attempts': 0,
#   'Holdsetup': {'Id': 1,
#    'Description': 'MoonBoard 2016',
#    'Setby': None,
#    'DateInserted': None,
#    'DateUpdated': None,
#    'DateDeleted': None,
#    'IsLocked': False,
#    'IsMini': False,
#    'Active': False,
#    'Holdsets': None,
#    'MoonBoardConfigurations': None,
#    'HoldLayoutId': 0,
#    'AllowClimbMethods': False},
#   'IsBenchmark': False,
#   'IsMaster': False,
#   'IsAssessmentProblem': False,
#   'ProblemType': None,
#   'Moves': [{'Id': 1518045,
#     'Description': 'D3',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 1518046, 'Description': 'B4', 'IsStart': True, 'IsEnd': False},
#    {'Id': 1518047, 'Description': 'C7', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518048, 'Description': 'F9', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518049, 'Description': 'C12', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518050, 'Description': 'D13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518051, 'Description': 'A16', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518052, 'Description': 'C18', 'IsStart': False, 'IsEnd': True}],
#   'Holdsets': None,
#   'Locations': [{'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 95,
#     'Y': 188,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 145,
#     'Y': 786,
#     'Color': '0x00FF00',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 195,
#     'Y': 638,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 195,
#     'Y': 388,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 195,
#     'Y': 88,
#     'Color': '0xFF0000',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 245,
#     'Y': 336,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 245,
#     'Y': 836,
#     'Color': '0x00FF00',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 345,
#     'Y': 536,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'}],
#   'RepeatText': '308 climbers  have repeated this problem',
#   'NumberOfTries': None,
#   'NameForUrl': 'shortround',
#   'Upgraded': False,
#   'Downgraded': False,
#   'Id': 19221,
#   'ApiId': 19221,
#   'DateInserted': '/Date(1456826427000)/',
#   'DateUpdated': None,
#   'DateDeleted': None,
#   'DateTimeString': '01 Mar 2016 10:00'},
#  {'Method': 'Feet follow hands',
#   'Name': 'CRIME AND PUNISHMENT',
#   'Grade': '7B',
#   'UserGrade': '7B',
#   'MoonBoardConfiguration': None,
#   'MoonBoardConfigurationId': 0,
#   'Setter': {'Id': '5FC09F63-05F3-4DAE-A1A5-3AC22C37139A',
#    'Nickname': 'Ben Moon',
#    'Firstname': 'Ben',
#    'Lastname': 'Moon',
#    'City': 'Sheffield',
#    'Country': 'United Kingdom',
#    'ProfileImageUrl': '/Content/Account/Users/Profile/5FC09F63-05F3-4DAE-A1A5-3AC22C37139A.jpeg?637253886697554113',
#    'CanShareData': True},
#   'FirstAscender': False,
#   'Rating': 0,
#   'UserRating': 2,
#   'Repeats': 225,
#   'Attempts': 0,
#   'Holdsetup': {'Id': 1,
#    'Description': 'MoonBoard 2016',
#    'Setby': None,
#    'DateInserted': None,
#    'DateUpdated': None,
#    'DateDeleted': None,
#    'IsLocked': False,
#    'IsMini': False,
#    'Active': False,
#    'Holdsets': None,
#    'MoonBoardConfigurations': None,
#    'HoldLayoutId': 0,
#    'AllowClimbMethods': False},
#   'IsBenchmark': False,
#   'IsMaster': False,
#   'IsAssessmentProblem': False,
#   'ProblemType': None,
#   'Moves': [{'Id': 1518038,
#     'Description': 'D3',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 1518039, 'Description': 'D6', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518040, 'Description': 'F9', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518041, 'Description': 'I12', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518042, 'Description': 'D13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518043, 'Description': 'D16', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518044, 'Description': 'C18', 'IsStart': False, 'IsEnd': True}],
#   'Holdsets': None,
#   'Locations': [{'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 195,
#     'Y': 88,
#     'Color': '0xFF0000',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 245,
#     'Y': 186,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 245,
#     'Y': 336,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 245,
#     'Y': 686,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 245,
#     'Y': 836,
#     'Color': '0x00FF00',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 345,
#     'Y': 536,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 495,
#     'Y': 388,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'}],
#   'RepeatText': '225 climbers  have repeated this problem',
#   'NumberOfTries': None,
#   'NameForUrl': 'crime-and-punishment',
#   'Upgraded': False,
#   'Downgraded': False,
#   'Id': 19220,
#   'ApiId': 19220,
#   'DateInserted': '/Date(1456826415000)/',
#   'DateUpdated': None,
#   'DateDeleted': None,
#   'DateTimeString': '01 Mar 2016 10:00'},
#  {'Method': 'Feet follow hands',
#   'Name': 'PROBLEM 5',
#   'Grade': '7A',
#   'UserGrade': '7A',
#   'MoonBoardConfiguration': None,
#   'MoonBoardConfigurationId': 0,
#   'Setter': {'Id': 'CC7D7BD1-67CD-4027-A537-22E7855C18B7',
#    'Nickname': 'Ally Patrick',
#    'Firstname': 'Alistair',
#    'Lastname': 'Patrick',
#    'City': 'Manchester',
#    'Country': 'United Kingdom',
#    'ProfileImageUrl': '/Content/Account/Images/default-profile.png?637253886697554113',
#    'CanShareData': True},
#   'FirstAscender': False,
#   'Rating': 0,
#   'UserRating': 3,
#   'Repeats': 94,
#   'Attempts': 0,
#   'Holdsetup': {'Id': 1,
#    'Description': 'MoonBoard 2016',
#    'Setby': None,
#    'DateInserted': None,
#    'DateUpdated': None,
#    'DateDeleted': None,
#    'IsLocked': False,
#    'IsMini': False,
#    'Active': False,
#    'Holdsets': None,
#    'MoonBoardConfigurations': None,
#    'HoldLayoutId': 0,
#    'AllowClimbMethods': False},
#   'IsBenchmark': False,
#   'IsMaster': False,
#   'IsAssessmentProblem': False,
#   'ProblemType': None,
#   'Moves': [{'Id': 1518030,
#     'Description': 'C5',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 1518031, 'Description': 'D7', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518032, 'Description': 'A9', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518033, 'Description': 'F11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518034, 'Description': 'F13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518035, 'Description': 'I14', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518036, 'Description': 'E16', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518037, 'Description': 'D18', 'IsStart': False, 'IsEnd': True}],
#   'Holdsets': None,
#   'Locations': [{'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 95,
#     'Y': 538,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 195,
#     'Y': 738,
#     'Color': '0x00FF00',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 245,
#     'Y': 86,
#     'Color': '0xFF0000',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 245,
#     'Y': 636,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 295,
#     'Y': 188,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 345,
#     'Y': 336,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 345,
#     'Y': 436,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 495,
#     'Y': 288,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'}],
#   'RepeatText': '94 climbers  have repeated this problem',
#   'NumberOfTries': None,
#   'NameForUrl': 'problem-5',
#   'Upgraded': False,
#   'Downgraded': False,
#   'Id': 19219,
#   'ApiId': 19219,
#   'DateInserted': '/Date(1456826415000)/',
#   'DateUpdated': None,
#   'DateDeleted': None,
#   'DateTimeString': '01 Mar 2016 10:00'},
#  {'Method': 'Feet follow hands',
#   'Name': 'HARD TIMES',
#   'Grade': '7A',
#   'UserGrade': '7A',
#   'MoonBoardConfiguration': None,
#   'MoonBoardConfigurationId': 0,
#   'Setter': {'Id': '5FC09F63-05F3-4DAE-A1A5-3AC22C37139A',
#    'Nickname': 'Ben Moon',
#    'Firstname': 'Ben',
#    'Lastname': 'Moon',
#    'City': 'Sheffield',
#    'Country': 'United Kingdom',
#    'ProfileImageUrl': '/Content/Account/Users/Profile/5FC09F63-05F3-4DAE-A1A5-3AC22C37139A.jpeg?637253886729638843',
#    'CanShareData': True},
#   'FirstAscender': False,
#   'Rating': 0,
#   'UserRating': 3,
#   'Repeats': 4445,
#   'Attempts': 0,
#   'Holdsetup': {'Id': 1,
#    'Description': 'MoonBoard 2016',
#    'Setby': None,
#    'DateInserted': None,
#    'DateUpdated': None,
#    'DateDeleted': None,
#    'IsLocked': False,
#    'IsMini': False,
#    'Active': False,
#    'Holdsets': None,
#    'MoonBoardConfigurations': None,
#    'HoldLayoutId': 0,
#    'AllowClimbMethods': False},
#   'IsBenchmark': True,
#   'IsMaster': False,
#   'IsAssessmentProblem': False,
#   'ProblemType': 'Crimp',
#   'Moves': [{'Id': 1844764,
#     'Description': 'B10',
#     'IsStart': False,
#     'IsEnd': False},
#    {'Id': 1844765, 'Description': 'E6', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1844766, 'Description': 'E8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1844767, 'Description': 'E12', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1844768, 'Description': 'E16', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1844769, 'Description': 'G4', 'IsStart': True, 'IsEnd': False},
#    {'Id': 1844770, 'Description': 'I18', 'IsStart': False, 'IsEnd': True},
#    {'Id': 1844771, 'Description': 'J5', 'IsStart': True, 'IsEnd': False}],
#   'Holdsets': None,
#   'Locations': [{'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 145,
#     'Y': 486,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 295,
#     'Y': 688,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 295,
#     'Y': 588,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 295,
#     'Y': 388,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 295,
#     'Y': 188,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 395,
#     'Y': 788,
#     'Color': '0x00FF00',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 495,
#     'Y': 88,
#     'Color': '0xFF0000',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 545,
#     'Y': 736,
#     'Color': '0x00FF00',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'}],
#   'RepeatText': '4445 climbers  have repeated this problem',
#   'NumberOfTries': None,
#   'NameForUrl': 'hard-times',
#   'Upgraded': False,
#   'Downgraded': False,
#   'Id': 19218,
#   'ApiId': 19218,
#   'DateInserted': '/Date(1456826415000)/',
#   'DateUpdated': None,
#   'DateDeleted': None,
#   'DateTimeString': '01 Mar 2016 10:00'},
#  {'Method': 'Feet follow hands',
#   'Name': 'PROBLEM 3',
#   'Grade': '6B+',
#   'UserGrade': '6B+',
#   'MoonBoardConfiguration': None,
#   'MoonBoardConfigurationId': 0,
#   'Setter': {'Id': 'CC7D7BD1-67CD-4027-A537-22E7855C18B7',
#    'Nickname': 'Ally Patrick',
#    'Firstname': 'Alistair',
#    'Lastname': 'Patrick',
#    'City': 'Manchester',
#    'Country': 'United Kingdom',
#    'ProfileImageUrl': '/Content/Account/Images/default-profile.png?637253886730107591',
#    'CanShareData': True},
#   'FirstAscender': False,
#   'Rating': 0,
#   'UserRating': 2,
#   'Repeats': 228,
#   'Attempts': 0,
#   'Holdsetup': {'Id': 1,
#    'Description': 'MoonBoard 2016',
#    'Setby': None,
#    'DateInserted': None,
#    'DateUpdated': None,
#    'DateDeleted': None,
#    'IsLocked': False,
#    'IsMini': False,
#    'Active': False,
#    'Holdsets': None,
#    'MoonBoardConfigurations': None,
#    'HoldLayoutId': 0,
#    'AllowClimbMethods': False},
#   'IsBenchmark': False,
#   'IsMaster': False,
#   'IsAssessmentProblem': False,
#   'ProblemType': None,
#   'Moves': [{'Id': 1518015,
#     'Description': 'F5',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 1518016, 'Description': 'J5', 'IsStart': True, 'IsEnd': False},
#    {'Id': 1518017, 'Description': 'F9', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518018, 'Description': 'C10', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518019, 'Description': 'G13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518020, 'Description': 'E15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518021, 'Description': 'I18', 'IsStart': False, 'IsEnd': True}],
#   'Holdsets': None,
#   'Locations': [{'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 195,
#     'Y': 488,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 295,
#     'Y': 238,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 345,
#     'Y': 536,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 345,
#     'Y': 736,
#     'Color': '0x00FF00',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 395,
#     'Y': 338,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 495,
#     'Y': 88,
#     'Color': '0xFF0000',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 545,
#     'Y': 736,
#     'Color': '0x00FF00',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'}],
#   'RepeatText': '228 climbers  have repeated this problem',
#   'NumberOfTries': None,
#   'NameForUrl': 'problem-3',
#   'Upgraded': False,
#   'Downgraded': False,
#   'Id': 19217,
#   'ApiId': 19217,
#   'DateInserted': '/Date(1456826416000)/',
#   'DateUpdated': None,
#   'DateDeleted': None,
#   'DateTimeString': '01 Mar 2016 10:00'},
#  {'Method': 'Feet follow hands',
#   'Name': 'WUTHERING HEIGHTS',
#   'Grade': '6B+',
#   'UserGrade': '6B+',
#   'MoonBoardConfiguration': None,
#   'MoonBoardConfigurationId': 0,
#   'Setter': {'Id': '5FC09F63-05F3-4DAE-A1A5-3AC22C37139A',
#    'Nickname': 'Ben Moon',
#    'Firstname': 'Ben',
#    'Lastname': 'Moon',
#    'City': 'Sheffield',
#    'Country': 'United Kingdom',
#    'ProfileImageUrl': '/Content/Account/Users/Profile/5FC09F63-05F3-4DAE-A1A5-3AC22C37139A.jpeg?637253887028522195',
#    'CanShareData': True},
#   'FirstAscender': False,
#   'Rating': 0,
#   'UserRating': 3,
#   'Repeats': 13445,
#   'Attempts': 0,
#   'Holdsetup': {'Id': 1,
#    'Description': 'MoonBoard 2016',
#    'Setby': None,
#    'DateInserted': None,
#    'DateUpdated': None,
#    'DateDeleted': None,
#    'IsLocked': False,
#    'IsMini': False,
#    'Active': False,
#    'Holdsets': None,
#    'MoonBoardConfigurations': None,
#    'HoldLayoutId': 0,
#    'AllowClimbMethods': False},
#   'IsBenchmark': True,
#   'IsMaster': False,
#   'IsAssessmentProblem': False,
#   'ProblemType': None,
#   'Moves': [{'Id': 1518007,
#     'Description': 'F5',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 1518008, 'Description': 'J8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518009, 'Description': 'I11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518010, 'Description': 'K11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518011, 'Description': 'G13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518012, 'Description': 'E15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518013, 'Description': 'E18', 'IsStart': False, 'IsEnd': True}],
#   'Holdsets': None,
#   'Locations': [{'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 295,
#     'Y': 238,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 295,
#     'Y': 88,
#     'Color': '0xFF0000',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 345,
#     'Y': 736,
#     'Color': '0x00FF00',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 395,
#     'Y': 338,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 495,
#     'Y': 438,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 545,
#     'Y': 586,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 595,
#     'Y': 438,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'}],
#   'RepeatText': '13445 climbers  have repeated this problem',
#   'NumberOfTries': None,
#   'NameForUrl': 'wuthering-heights',
#   'Upgraded': False,
#   'Downgraded': False,
#   'Id': 19216,
#   'ApiId': 19216,
#   'DateInserted': '/Date(1456826427000)/',
#   'DateUpdated': None,
#   'DateDeleted': None,
#   'DateTimeString': '01 Mar 2016 10:00'},
#  {'Method': 'Feet follow hands',
#   'Name': 'FAR FROM THE MADDING CROWD',
#   'Grade': '6B+',
#   'UserGrade': '6B+',
#   'MoonBoardConfiguration': None,
#   'MoonBoardConfigurationId': 0,
#   'Setter': {'Id': '5FC09F63-05F3-4DAE-A1A5-3AC22C37139A',
#    'Nickname': 'Ben Moon',
#    'Firstname': 'Ben',
#    'Lastname': 'Moon',
#    'City': 'Sheffield',
#    'Country': 'United Kingdom',
#    'ProfileImageUrl': '/Content/Account/Users/Profile/5FC09F63-05F3-4DAE-A1A5-3AC22C37139A.jpeg?637253887175628990',
#    'CanShareData': True},
#   'FirstAscender': False,
#   'Rating': 0,
#   'UserRating': 3,
#   'Repeats': 10197,
#   'Attempts': 0,
#   'Holdsetup': {'Id': 1,
#    'Description': 'MoonBoard 2016',
#    'Setby': None,
#    'DateInserted': None,
#    'DateUpdated': None,
#    'DateDeleted': None,
#    'IsLocked': False,
#    'IsMini': False,
#    'Active': False,
#    'Holdsets': None,
#    'MoonBoardConfigurations': None,
#    'HoldLayoutId': 0,
#    'AllowClimbMethods': False},
#   'IsBenchmark': True,
#   'IsMaster': False,
#   'IsAssessmentProblem': False,
#   'ProblemType': None,
#   'Moves': [{'Id': 1518000,
#     'Description': 'E6',
#     'IsStart': True,
#     'IsEnd': False},
#    {'Id': 1518001, 'Description': 'C5', 'IsStart': True, 'IsEnd': False},
#    {'Id': 1518002, 'Description': 'E8', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518003, 'Description': 'F11', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518004, 'Description': 'C13', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518005, 'Description': 'D15', 'IsStart': False, 'IsEnd': False},
#    {'Id': 1518006, 'Description': 'D18', 'IsStart': False, 'IsEnd': True}],
#   'Holdsets': None,
#   'Locations': [{'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 195,
#     'Y': 738,
#     'Color': '0x00FF00',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 195,
#     'Y': 338,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 245,
#     'Y': 86,
#     'Color': '0xFF0000',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 245,
#     'Y': 236,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 295,
#     'Y': 688,
#     'Color': '0x00FF00',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 295,
#     'Y': 588,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'},
#    {'Id': 0,
#     'Holdset': None,
#     'Description': None,
#     'X': 345,
#     'Y': 436,
#     'Color': '0x0000FF',
#     'Rotation': 0,
#     'Type': 0,
#     'HoldNumber': None,
#     'Direction': 0,
#     'DirectionString': 'N'}],
#   'RepeatText': '10197 climbers  have repeated this problem',
#   'NumberOfTries': None,
#   'NameForUrl': 'far-from-the-madding-crowd',
#   'Upgraded': False,
#   'Downgraded': False,
#   'Id': 19215,
#   'ApiId': 19215,
#   'DateInserted': '/Date(1456826427000)/',
#   'DateUpdated': None,
#   'DateDeleted': None,
#   'DateTimeString': '01 Mar 2016 10:00'}]
#                Method                        Name Grade UserGrade  \
# 0   Feet follow hands                  PROBLEM 14    7B      None
# 1   Feet follow hands                  PROBLEM 13    7A        7A
# 2   Feet follow hands                  PROBLEM 12    7B      None
# 3   Feet follow hands                  PROBLEM 11    7A        7A
# 4   Feet follow hands                        TESS   6C+       6C+
# 5   Feet follow hands                   PROBLEM 9   7A+       7A+
# 6   Feet follow hands                        VURT    7B        7B
# 7   Feet follow hands                  SHORTROUND   6C+       6C+
# 8   Feet follow hands        CRIME AND PUNISHMENT    7B        7B
# 9   Feet follow hands                   PROBLEM 5    7A        7A
# 10  Feet follow hands                  HARD TIMES    7A        7A
# 11  Feet follow hands                   PROBLEM 3   6B+       6B+
# 12  Feet follow hands           WUTHERING HEIGHTS   6B+       6B+
# 13  Feet follow hands  FAR FROM THE MADDING CROWD   6B+       6B+
#
#    MoonBoardConfiguration  MoonBoardConfigurationId  \
# 0                    None                         0
# 1                    None                         0
# 2                    None                         0
# 3                    None                         0
# 4                    None                         0
# 5                    None                         0
# 6                    None                         0
# 7                    None                         0
# 8                    None                         0
# 9                    None                         0
# 10                   None                         0
# 11                   None                         0
# 12                   None                         0
# 13                   None                         0
#
#                                                Setter  FirstAscender  Rating  \
# 0   {'Id': '48B03D33-7FB0-43A9-BC1C-F9B75B2EFA13',...          False       0
# 1   {'Id': '48B03D33-7FB0-43A9-BC1C-F9B75B2EFA13',...          False       0
# 2   {'Id': '48B03D33-7FB0-43A9-BC1C-F9B75B2EFA13',...          False       0
# 3   {'Id': '48B03D33-7FB0-43A9-BC1C-F9B75B2EFA13',...          False       0
# 4   {'Id': '5FC09F63-05F3-4DAE-A1A5-3AC22C37139A',...          False       0
# 5   {'Id': 'CC7D7BD1-67CD-4027-A537-22E7855C18B7',...          False       0
# 6   {'Id': '5FC09F63-05F3-4DAE-A1A5-3AC22C37139A',...          False       0
# 7   {'Id': 'CC7D7BD1-67CD-4027-A537-22E7855C18B7',...          False       0
# 8   {'Id': '5FC09F63-05F3-4DAE-A1A5-3AC22C37139A',...          False       0
# 9   {'Id': 'CC7D7BD1-67CD-4027-A537-22E7855C18B7',...          False       0
# 10  {'Id': '5FC09F63-05F3-4DAE-A1A5-3AC22C37139A',...          False       0
# 11  {'Id': 'CC7D7BD1-67CD-4027-A537-22E7855C18B7',...          False       0
# 12  {'Id': '5FC09F63-05F3-4DAE-A1A5-3AC22C37139A',...          False       0
# 13  {'Id': '5FC09F63-05F3-4DAE-A1A5-3AC22C37139A',...          False       0
#
#     UserRating  ...  NumberOfTries                  NameForUrl Upgraded  \
# 0            3  ...           None                  problem-14    False
# 1            3  ...           None                  problem-13    False
# 2            3  ...           None                  problem-12    False
# 3            3  ...           None                  problem-11    False
# 4            3  ...           None                        tess    False
# 5            3  ...           None                   problem-9    False
# 6            3  ...           None                        vurt    False
# 7            3  ...           None                  shortround    False
# 8            2  ...           None        crime-and-punishment    False
# 9            3  ...           None                   problem-5    False
# 10           3  ...           None                  hard-times    False
# 11           2  ...           None                   problem-3    False
# 12           3  ...           None           wuthering-heights    False
# 13           3  ...           None  far-from-the-madding-crowd    False
#
#     Downgraded     Id  ApiId           DateInserted DateUpdated DateDeleted  \
# 0        False  19228  19228  /Date(1456826414000)/        None        None
# 1        False  19227  19227  /Date(1456826414000)/        None        None
# 2        False  19226  19226  /Date(1456826415000)/        None        None
# 3        False  19225  19225  /Date(1456826414000)/        None        None
# 4        False  19224  19224  /Date(1456826415000)/        None        None
# 5        False  19223  19223  /Date(1456826415000)/        None        None
# 6        False  19222  19222  /Date(1456826415000)/        None        None
# 7        False  19221  19221  /Date(1456826427000)/        None        None
# 8        False  19220  19220  /Date(1456826415000)/        None        None
# 9        False  19219  19219  /Date(1456826415000)/        None        None
# 10       False  19218  19218  /Date(1456826415000)/        None        None
# 11       False  19217  19217  /Date(1456826416000)/        None        None
# 12       False  19216  19216  /Date(1456826427000)/        None        None
# 13       False  19215  19215  /Date(1456826427000)/        None        None
#
#        DateTimeString
# 0   01 Mar 2016 10:00
# 1   01 Mar 2016 10:00
# 2   01 Mar 2016 10:00
# 3   01 Mar 2016 10:00
# 4   01 Mar 2016 10:00
# 5   01 Mar 2016 10:00
# 6   01 Mar 2016 10:00
# 7   01 Mar 2016 10:00
# 8   01 Mar 2016 10:00
# 9   01 Mar 2016 10:00
# 10  01 Mar 2016 10:00
# 11  01 Mar 2016 10:00
# 12  01 Mar 2016 10:00
# 13  01 Mar 2016 10:00
#
# [14 rows x 31 columns]

# %% [markdown]
# Cool, so from_records will accept a list of dicts. Let's concat all of df's 'Data' cells (each is a series) and then bring it back to a df.

# %%
all_problem_dicts = sum([l for l in df['Data']], [])
problems = pd.DataFrame.from_records(all_problem_dicts)
display(problems.sample(10))
display(problems.iloc[0])
# Out:
#                   Method                 Name Grade UserGrade  \
# 24316  Feet follow hands   FOR JAPAN’S FRIEND   7A+      None
# 25235  Feet follow hands       FÜR DIE LOOSER   6B+      None
# 30856  Feet follow hands         FOR SIERRA 1   7A+      None
# 26320  Feet follow hands             BUG BOYZ   7A+      None
# 30673  Feet follow hands     ACIDO SOLFIDRICO    6C      None
# 19799  Feet follow hands  YANG BOARD : KI TOP   6B+      None
# 19706  Feet follow hands     CHANGE THE MUSIC    6C      None
# 402    Feet follow hands      VALENTINA NAPPI    7B        7B
# 19474  Feet follow hands            ACID RAIN   7B+      None
# 27502  Feet follow hands        GERMAIN CLIMB   6C+      None
#
#       MoonBoardConfiguration  MoonBoardConfigurationId  \
# 24316                   None                         0
# 25235                   None                         0
# 30856                   None                         0
# 26320                   None                         0
# 30673                   None                         0
# 19799                   None                         0
# 19706                   None                         0
# 402                     None                         0
# 19474                   None                         0
# 27502                   None                         0
#
#                                                   Setter  FirstAscender  \
# 24316  {'Id': '90035C3B-87D0-42E4-BD5F-9E3BB2E00700',...          False
# 25235  {'Id': '6da1997e-0f52-40fe-9777-eab049b76e32',...          False
# 30856  {'Id': '5EC72B46-B5C4-436F-9CDE-6E4D1078A3FC',...          False
# 26320  {'Id': 'afbc0fef-7f7b-494e-9e62-433c52dcad32',...          False
# 30673  {'Id': '86a697a1-dacb-46fe-8213-d5912ed3a9a5',...          False
# 19799  {'Id': 'd6e19e3c-6912-4f8d-bbd9-f8c64efe9934',...          False
# 19706  {'Id': '857f2b44-8154-4b11-8374-2efbb768e0bd',...          False
# 402    {'Id': 'BC1EB6AE-3997-41B0-B6FB-0A6CAC8C3F1D',...          False
# 19474  {'Id': '43750C95-08B4-4A32-8435-46D5F66EEFAA',...          False
# 27502  {'Id': 'a6eb8656-c273-4b77-bf6b-81600ebca998',...          False
#
#        Rating  UserRating  ...  NumberOfTries          NameForUrl Upgraded  \
# 24316       0           0  ...           None  for-japan-s-friend    False
# 25235       0           2  ...           None      für-die-looser    False
# 30856       0           2  ...           None        for-sierra-1    False
# 26320       0           0  ...           None            bug-boyz    False
# 30673       0           2  ...           None    acido-solfidrico    False
# 19799       0           3  ...           None   yang-board-ki-top    False
# 19706       0           3  ...           None    change-the-music    False
# 402         0           3  ...           None     valentina-nappi    False
# 19474       0           0  ...           None           acid-rain    False
# 27502       0           2  ...           None       germain-climb    False
#
#        Downgraded      Id  ApiId           DateInserted DateUpdated  \
# 24316       False  348972      0  /Date(1564045059220)/        None
# 25235       False  351537      0  /Date(1567441645553)/        None
# 30856       False  368513      0  /Date(1588640758360)/        None
# 26320       False  354515      0  /Date(1572216892337)/        None
# 30673       False  367731      0  /Date(1587289907977)/        None
# 19799       False  335865      0  /Date(1548409522397)/        None
# 19706       False  335560      0  /Date(1548154892147)/        None
# 402         False   24466  24466  /Date(1466088387000)/        None
# 19474       False  334899      0  /Date(1547506895030)/        None
# 27502       False  358237      0  /Date(1576442223430)/        None
#
#       DateDeleted     DateTimeString
# 24316        None  25 Jul 2019 09:57
# 25235        None  02 Sep 2019 17:27
# 30856        None  05 May 2020 02:05
# 26320        None  27 Oct 2019 22:54
# 30673        None  19 Apr 2020 10:51
# 19799        None  25 Jan 2019 09:45
# 19706        None  22 Jan 2019 11:01
# 402          None  16 Jun 2016 15:46
# 19474        None  14 Jan 2019 23:01
# 27502        None  15 Dec 2019 20:37
#
# [10 rows x 31 columns]
# Method                                                      Feet follow hands
# Name                                                               PROBLEM 14
# Grade                                                                      7B
# UserGrade                                                                None
# MoonBoardConfiguration                                                   None
# MoonBoardConfigurationId                                                    0
# Setter                      {'Id': '48B03D33-7FB0-43A9-BC1C-F9B75B2EFA13',...
# FirstAscender                                                           False
# Rating                                                                      0
# UserRating                                                                  3
# Repeats                                                                     3
# Attempts                                                                    0
# Holdsetup                   {'Id': 1, 'Description': 'MoonBoard 2016', 'Se...
# IsBenchmark                                                             False
# IsMaster                                                                False
# IsAssessmentProblem                                                     False
# ProblemType                                                              None
# Moves                       [{'Id': 1518093, 'Description': 'G4', 'IsStart...
# Holdsets                                                                 None
# Locations                   [{'Id': 0, 'Holdset': None, 'Description': Non...
# RepeatText                             3 climbers  have repeated this problem
# NumberOfTries                                                            None
# NameForUrl                                                         problem-14
# Upgraded                                                                False
# Downgraded                                                              False
# Id                                                                      19228
# ApiId                                                                   19228
# DateInserted                                            /Date(1456826414000)/
# DateUpdated                                                              None
# DateDeleted                                                              None
# DateTimeString                                              01 Mar 2016 10:00
# Name: 0, dtype: object

# %% [markdown]
# From here we'll save all problem data for posterity before getting specifically to the columns that are likely relevant for us.

# %%
problems.to_csv('data/raw_probs.csv', index=False)

# %%
print(problems['Setter'][0])
print(problems['Holdsetup'][0])
print(problems['Moves'][0])
print(problems['Locations'][0])
# Out:
# {'Id': '48B03D33-7FB0-43A9-BC1C-F9B75B2EFA13', 'Nickname': 'lucas Dourdourekas', 'Firstname': 'lucas', 'Lastname': 'Dourdourekas', 'City': 'Kalymnos', 'Country': 'GREECE ', 'ProfileImageUrl': '/Content/Account/Images/default-profile.png?637253886636747434', 'CanShareData': True}
# {'Id': 1, 'Description': 'MoonBoard 2016', 'Setby': None, 'DateInserted': None, 'DateUpdated': None, 'DateDeleted': None, 'IsLocked': False, 'IsMini': False, 'Active': False, 'Holdsets': None, 'MoonBoardConfigurations': None, 'HoldLayoutId': 0, 'AllowClimbMethods': False}
# [{'Id': 1518093, 'Description': 'G4', 'IsStart': True, 'IsEnd': False}, {'Id': 1518094, 'Description': 'B7', 'IsStart': False, 'IsEnd': False}, {'Id': 1518095, 'Description': 'G8', 'IsStart': False, 'IsEnd': False}, {'Id': 1518096, 'Description': 'D11', 'IsStart': False, 'IsEnd': False}, {'Id': 1518097, 'Description': 'C13', 'IsStart': False, 'IsEnd': False}, {'Id': 1518098, 'Description': 'G17', 'IsStart': False, 'IsEnd': False}, {'Id': 1518099, 'Description': 'I18', 'IsStart': False, 'IsEnd': True}]
# [{'Id': 0, 'Holdset': None, 'Description': None, 'X': 145, 'Y': 636, 'Color': '0x0000FF', 'Rotation': 0, 'Type': 0, 'HoldNumber': None, 'Direction': 0, 'DirectionString': 'N'}, {'Id': 0, 'Holdset': None, 'Description': None, 'X': 195, 'Y': 338, 'Color': '0x0000FF', 'Rotation': 0, 'Type': 0, 'HoldNumber': None, 'Direction': 0, 'DirectionString': 'N'}, {'Id': 0, 'Holdset': None, 'Description': None, 'X': 245, 'Y': 436, 'Color': '0x0000FF', 'Rotation': 0, 'Type': 0, 'HoldNumber': None, 'Direction': 0, 'DirectionString': 'N'}, {'Id': 0, 'Holdset': None, 'Description': None, 'X': 395, 'Y': 788, 'Color': '0x00FF00', 'Rotation': 0, 'Type': 0, 'HoldNumber': None, 'Direction': 0, 'DirectionString': 'N'}, {'Id': 0, 'Holdset': None, 'Description': None, 'X': 395, 'Y': 588, 'Color': '0x0000FF', 'Rotation': 0, 'Type': 0, 'HoldNumber': None, 'Direction': 0, 'DirectionString': 'N'}, {'Id': 0, 'Holdset': None, 'Description': None, 'X': 395, 'Y': 138, 'Color': '0x0000FF', 'Rotation': 0, 'Type': 0, 'HoldNumber': None, 'Direction': 0, 'DirectionString': 'N'}, {'Id': 0, 'Holdset': None, 'Description': None, 'X': 495, 'Y': 88, 'Color': '0xFF0000', 'Rotation': 0, 'Type': 0, 'HoldNumber': None, 'Direction': 0, 'DirectionString': 'N'}]

# %%
print((problems['Method'] != 'Feet follow hands').any())
print((~problems['MoonBoardConfiguration'].isnull()).any())
print((problems['MoonBoardConfigurationId'] != 0).any())
print((problems['Holdsetup'] != problems['Holdsetup'][0]).any())
print(problems['Upgraded'].any())
print(problems['Downgraded'].any())
print((~problems['NumberOfTries'].isnull()).any())
print((problems['Rating'] != 0).any())
# Out:
# False
# False
# False
# False
# False
# False
# False
# False

# %%
print((~problems['IsAssessmentProblem']).any())
print((~problems['IsMaster']).any())
print((~problems['IsBenchmark']).any())
print(len(problems['Grade'] != problems['UserGrade']))
print(len(problems.loc[~problems['ProblemType'].isnull()]))
# Out:
# True
# True
# True
# 31034
# 54

# %% [markdown]
# Of the deeper cells, it looks like Moves is the only really important one, and Setter is the problem setter's info. Many columns are uninformative (the same for the whole dataset). For some reason, 53 of these problems are of ProblemType 'Crimp.'

# %% [markdown]
# ### Selection, formatting

# %%
cols2keep = ['Name', 'Grade', 'UserGrade', 'Setter', 'UserRating', 'Repeats', 'IsBenchmark',
             'IsMaster', 'IsAssessmentProblem', 'ProblemType', 'Moves', 'DateTimeString']

probs_clean = problems[cols2keep].copy()  # We do copy() because of column-adding operations next
probs_clean.sample(5)
# Out:
#                      Name Grade UserGrade  \
# 15     USE THE FORCE LUKE    7B        7B
# 7453      EASY FIRST MOVE    7C        7C
# 22824            RISCALDO   6B+      None
# 8111       LUNGE AND DUNK    7A      None
# 8140      HEALING PROCESS    7C      None
#
#                                                   Setter  UserRating  Repeats  \
# 15     {'Id': 'B3B553F1-1736-4F9D-AD93-6DF3DDFB6F04',...           2       52
# 7453   {'Id': '9349AC41-37B1-4769-BE92-EA095D67BEBE',...           2       18
# 22824  {'Id': 'b02cc483-f551-4db4-b22f-d5bccbe22bdd',...           2       13
# 8111   {'Id': '2D5F73B0-3B4F-49DB-B03A-7F94D59BA29A',...           2        4
# 8140   {'Id': '54F2AD4C-905F-454C-9455-36C0C927DD64',...           3        2
#
#        IsBenchmark  IsMaster  IsAssessmentProblem ProblemType  \
# 15           False     False                False        None
# 7453         False     False                False        None
# 22824        False     False                False        None
# 8111         False     False                False        None
# 8140         False     False                False        None
#
#                                                    Moves     DateTimeString
# 15     [{'Id': 1518189, 'Description': 'I4', 'IsStart...  06 Mar 2016 15:27
# 7453   [{'Id': 1602887, 'Description': 'D3', 'IsStart...  26 Aug 2017 15:10
# 22824  [{'Id': 1935558, 'Description': 'F5', 'IsStart...  21 May 2019 17:34
# 8111   [{'Id': 1609364, 'Description': 'B3', 'IsStart...  18 Sep 2017 21:12
# 8140   [{'Id': 1609701, 'Description': 'B4', 'IsStart...  19 Sep 2017 21:10

# %% [markdown]
# Only thing is that we want to expand on those deeper cells still (Moves and Setter).

# %%
# Expand on Setter info
setters = probs_clean['Setter']
keys = ['Firstname', 'Lastname', 'Nickname', 'City', 'Country']
for k in keys:
    vals = [s[k] for s in setters]
    probs_clean['Setter.%s' % k] = vals

# Expand on Moves info: filter moves by start, intermediate, end
moves = probs_clean['Moves']
def _moves2holdcols(dicts):
    start, intermed, end = [], [], []
    for d in dicts:
        if d['IsStart']: start.append(d['Description'].upper())
        elif d['IsEnd']: end.append(d['Description'].upper())
        else: intermed.append(d['Description'].upper())
    return [start, intermed, end]

# Add columns for holds
hold_cols = [_moves2holdcols(move_dicts) for move_dicts in moves]
probs_clean['Holds.Start'] = [h[0] for h in hold_cols]
probs_clean['Holds.Intermed'] = [h[1] for h in hold_cols]
probs_clean['Holds.End'] = [h[2] for h in hold_cols]

# Remove unexpanded cols
probs_clean.drop('Setter', axis=1, inplace=True)
probs_clean.drop('Moves', axis=1, inplace=True)

display(probs_clean.tail())
print(len(probs_clean))
# Out:
#                 Name Grade UserGrade  UserRating  Repeats  IsBenchmark  \
# 31029       24K GOLD   6C+      None           0        0        False
# 31030       14K GOLD   6B+      None           0        0        False
# 31031  CAREER LADDER   6B+      None           0        0        False
# 31032      UP & DOWN   6C+      None           0        0        False
# 31033    BOB’S KABOB    7A      None           0        0        False
#
#        IsMaster  IsAssessmentProblem ProblemType     DateTimeString  \
# 31029     False                False        None  17 May 2020 20:38
# 31030     False                False        None  17 May 2020 20:36
# 31031     False                False        None  17 May 2020 14:35
# 31032     False                False        None  17 May 2020 10:55
# 31033     False                False        None  17 May 2020 03:54
#
#       Setter.Firstname Setter.Lastname Setter.Nickname Setter.City  \
# 31029          Tiffany             Wen            Tiff      Denver
# 31030          Tiffany             Wen            Tiff      Denver
# 31031           Julian          Enzing           Enzko     Dresden
# 31032           Andrew         Aksenov      Andrew Aks        Tula
# 31033           Declan          Osgood   Declan Osgood  San Diego
#
#       Setter.Country Holds.Start                        Holds.Intermed  \
# 31029            USA        [I5]              [H9, D10, H14, C15, D16]
# 31030            USA        [I5]          [H9, I12, H14, C15, D13, F9]
# 31031        Germany        [I5]          [K5, G9, H10, G15, K14, I16]
# 31032         Russia    [H5, K5]  [J8, J9, G13, D12, B11, F6, C7, B16]
# 31033  United States    [B4, F6]           [K6, K9, K8, H12, G14, D16]
#
#       Holds.End
# 31029     [C18]
# 31030     [E18]
# 31031     [K18]
# 31032     [D18]
# 31033     [D18]
# 31034

# %% [markdown]
# ### Deduplication
#
# Here's our last step! Everything's about ready, but we may as well check for dups.
#
# Interestingly, there are some some problems that are identical in terms of holds but differ in terms of name, and often grade. We don't prune those; just those that are obviously accidental dups.

# %%
dups = probs_clean[probs_clean.applymap(lambda x: str(sorted(x)) if isinstance(x, list) else x).duplicated(['Holds.Start', 'Holds.Intermed', 'Holds.End'], keep=False)]
display(dups.sort_values('Holds.Start'))

names = dups[['Name', 'Setter.Nickname']]
dup_names = names[names.duplicated()]
display(dup_names)  # I'm not sure why some problems are still represented multiple times here; they shouldn't be
# Out:
#                      Name Grade UserGrade  UserRating  Repeats  IsBenchmark  \
# 5835               DAVIDS    7B      None           0        0        False
# 5836               DAVIDS    7B      None           3        2        False
# 3574          7A TOO MUCH   6C+       6C+           3     2214         True
# 29513        DOUBLES #1-2   6B+      None           2        2        False
# 30702  JUST KEEP SWIMMING    6C      None           0        0        False
# ...                   ...   ...       ...         ...      ...          ...
# 24255             CRAWLER   6C+      None           2       16        False
# 24254        MAMBA POISON    6C      None           3        8        False
# 3513           THUNDERMAN    6C       6C+           2      218        False
# 16580    BEST KEPT SECRET   7A+      None           3        1        False
# 16579    BEST KEPT SECRET   7A+      None           0        0        False
#
#        IsMaster  IsAssessmentProblem ProblemType     DateTimeString  \
# 5835      False                False        None  20 Jun 2017 15:30
# 5836      False                False        None  20 Jun 2017 15:30
# 3574      False                False        None  11 Mar 2017 06:59
# 29513     False                False        None  28 Feb 2020 01:07
# 30702     False                False        None  21 Apr 2020 20:28
# ...         ...                  ...         ...                ...
# 24255     False                False        None  23 Jul 2019 17:50
# 24254     False                False        None  23 Jul 2019 17:50
# 3513      False                False        None  08 Mar 2017 03:07
# 16580     False                False        None  07 Sep 2018 22:59
# 16579     False                False        None  07 Sep 2018 22:59
#
#       Setter.Firstname Setter.Lastname   Setter.Nickname        Setter.City  \
# 5835             Tommy          Skeide      Tommy Skeide            Ålesund
# 5836             Tommy          Skeide      Tommy Skeide            Ålesund
# 3574                CH             Kuo            CH Kuo             taIpei
# 29513              Ben    Khounsombath  Ben Khounsombath          Charlotte
# 30702             Dawn           Brown        Dawn Brown          Doncaster
# ...                ...             ...               ...                ...
# 24255         durukan             türe              ture             Mersin
# 24254        tolga han          edebal       yellowmamba          şanlıurfa
# 3513              Jack       McConnell    Jack McConnell  Colorado Springs
# 16580           Curtis         Labouff    Curtis Labouff          Las Vegas
# 16579           Curtis         Labouff    Curtis Labouff          Las Vegas
#
#        Setter.Country Holds.Start                 Holds.Intermed Holds.End
# 5835           NORWAY        [A5]             [C8, E8, F12, C14]     [C18]
# 5836           NORWAY        [A5]             [C8, E8, F12, C14]     [C18]
# 3574           TAIWAN    [A5, C5]       [E8, E10, G15, I12, J16]     [E18]
# 29513             USA    [A5, C5]       [E8, E10, I12, G15, J16]     [E18]
# 30702  United Kingdom    [A5, D5]       [D9, B11, B13, C16, F16]     [G18]
# ...               ...         ...                            ...       ...
# 24255          Turkey        [K5]  [J8, I11, H11, D12, D15, B16]     [E18]
# 24254          Turkey        [K5]  [J8, I11, H11, D12, D15, B16]     [E18]
# 3513              USA        [K5]       [J8, I10, H10, G13, E16]     [G18]
# 16580   UNITED STATES    [K5, D3]        [G9, F10, A12, B7, C15]     [A18]
# 16579   UNITED STATES    [K5, D3]        [G9, F10, A12, B7, C15]     [A18]
#
# [129 rows x 18 columns]
#                            Name            Setter.Nickname
# 2244                      ACG70                      bkkim
# 2368                 L'INSONNIA            antonio eremita
# 2537                 STILL DAVE               David Burian
# 4182                  FORSØK 39                    atoneni
# 5330                     UH-000               ulises huete
# 5441                  35 GRADER               Tommy Skeide
# 5521             SUMMER CAMP V2              Matthew Smith
# 5836                     DAVIDS               Tommy Skeide
# 7396              CHRIS PROBLEM       Christopher Pattberg
# 8185             FRANK THE TANK               Sean Decaire
# 8463       DON’T TRY THAT CLIMB               Jack Davison
# 9263              ВСЁ СНАЧАЛА№2             russian did it
# 9665           ЛЕГХКАЯ ПРОБЛЕМА           VASYA SKALOLAZKA
# 12558                   SNIKERS               Luzan Matyas
# 13652                DANG MAGIC                 Gus Carter
# 14208                    YUMMI!             Leta Dickinson
# 14368         THE LAST BIG BANG                 Gus Carter
# 14605  BZ - WALKING ON THE MOON               Thomas Watts
# 15258                  DIONYSUS       Alexander Firmberger
# 15861                  NOT MINE              IAmFrancoChan
# 15862                  NOT MINE              IAmFrancoChan
# 15943                       ELY  Taccheesvasi Taccheesvasi
# 16580          BEST KEPT SECRET             Curtis Labouff
# 16648                  RECEPÇÃO                     Otavio
# 18001            SON OF KRYPTON                      Chris
# 20565                      MEG1                     megoic
# 20887              JACK REACHER             Komjati Zoltan
# 21691               PIC A BANIC               Pseudosimian
# 23704            STARTERPROBLEM                     vietan
# 24492                ÖKC WARMUP                    Pitch13
# 26347                    KHONSU              AvTheWiscoKid
# 28287         V4 LEMON SQUEEZEY                     trooon
# 28644                AUSPROBIAT                     TonyST
# 29448                      P.20                      BAZIW
# 29449                      P.20                      BAZIW
# 29450                      P.20                      BAZIW
# 29452                      P.19                      BAZIW
# 29453                      P.19                      BAZIW
# 29454                      P.19                      BAZIW
# 29455                      P.19                      BAZIW
# 29456                      P.19                      BAZIW
# 30702        JUST KEEP SWIMMING                 Dawn Brown
# 30867            WHATS SO FUNNY                 Dawn Brown

# %%
keeps, drops = set(), set()

for _, (name, setter) in dup_names.iterrows():
    # Get all probs that have the same name and setter
    same_probs = dups[(dups['Name'] == name) & (dups['Setter.Nickname'] == setter)]
    repeats, ratings = same_probs['Repeats'], same_probs['UserRating']
    # Prefer higher repeats, then higher ratings, and otherwise newest
    if (repeats.iloc[0] != repeats.iloc[1:]).any():
        keep = repeats.idxmax()
    elif (ratings.iloc[0] != ratings.iloc[1:]).any():
        keep = ratings.idxmax()
    else:
        keep = same_probs.index[-1]
    # Keep the preferred prob and drop the rest
    keeps.add(keep)
    drops.update(set(same_probs.index) - set([keep]))

# %%
print('Keeping {} problems and dropping {}'.format(len(keeps), len(drops)))

probs_dedup = probs_clean.drop(drops).reset_index(drop=True)
# Out:
# Keeping 36 problems and dropping 43

# %%
probs_dedup.to_csv('data/cleaned_probs.csv', index=False)
probs_dedup.to_json('data/cleaned_probs.json', orient='records')

# %%
len(probs_dedup)
# Out:
# 30991

# %% [markdown]
# And we're done!
